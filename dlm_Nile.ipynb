# %%
install.packages("dlm")
library(dlm)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
build.1 <- function(theta){
dlmModPoly(order=1, dV=exp(theta[1]), dW=exp(theta[2]))
}

# %%
fit.1 <- dlmMLE(Nile, parm=c(1, 1), build.1)
mod.Nile <- build.1(fit.1$par)

# %%
NileFilt <- dlmFilter(Nile, mod.Nile)

# %%
NileSmooth <- dlmSmooth(NileFilt)

# %%
plot(Nile, type="o", col=8, pch = 4, ylab="", main="Nile Filtering")
lines(dropFirst(NileFilt$m), col=4, lwd=1)
lines(dropFirst(NileSmooth$s), col=2, lwd=1)
# Out:
# Plot with title “Nile Filtering”
